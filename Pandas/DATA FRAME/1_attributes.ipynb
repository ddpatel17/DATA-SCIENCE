# %%
import pandas as pd

# %%
s1 = pd.read_csv('../../Data/marine economy.csv')
s1.head()
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag
# 0  Proportion    Actual   LEED        42.1    F
# 1  Proportion    Actual   LEED        39.4    F
# 2  Proportion    Actual   LEED        39.9    R
# 3  Proportion    Actual   LEED        40.8    F
# 4  Proportion    Actual   LEED        39.9    F

# %%
result = pd.DataFrame(s1) # Returns the index (row labels) of the DataFrame.
result
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# ...

# %%
print(s1.index)
# Out:
# RangeIndex(start=0, stop=714, step=1)

# %%
print(result.index)
# Out:
# RangeIndex(start=0, stop=714, step=1)

# %%
print(s1.values)
# Out:
# [[2007 'Fisheries and aquaculture' 'Cont. to ME Wage and salary earners'
#   ... 'LEED' 42.1 'F']
#  [2008 'Fisheries and aquaculture' 'Cont. to ME Wage and salary earners'
#   ... 'LEED' 39.4 'F']
#  [2009 'Fisheries and aquaculture' 'Cont. to ME Wage and salary earners'
#   ... 'LEED' 39.9 'R']
#  ...
#  [2019 'Total marine economy' 'Wage and salary earners' ... 'LEED'
#   39867.0 'R']
#  [2020 'Total marine economy' 'Wage and salary earners' ... 'LEED'
#   40593.0 'P']
#  [2021 'Total marine economy' 'Wage and salary earners' ... 'LEED'
#   39474.0 'P']]

# %%
print(s1.dtypes)
# Out:
# year            int64
# category       object
# variable       object
# units          object
# magnitude      object
# source         object
# data_value    float64
# flag           object
# dtype: object

# %%
s1.columns
# Out:
# Index(['year', 'category', 'variable', 'units', 'magnitude', 'source',
#        'data_value', 'flag'],
#       dtype='object')

# %%
s1.shape
# Out:
# (714, 8)

# %%
s1.ndim
# Out:
# 2

# %%
s1.size
# Out:
# 5712

# %%
s1.empty
# Out:
# False

# %%
mask = s1.empty
mask
# Out:
# False

# %%
s1.axes
# Out:
# [RangeIndex(start=0, stop=714, step=1),
#  Index(['year', 'category', 'variable', 'units', 'magnitude', 'source',
#         'data_value', 'flag'],
#        dtype='object')]

# %%
s1.T
# Out:
#                                             0    \
# year                                       2007
# category              Fisheries and aquaculture
# variable    Cont. to ME Wage and salary earners
# units                                Proportion
# magnitude                                Actual
# source                                     LEED
# data_value                                 42.1
# flag                                          F
#
#                                             1    \
# year                                       2008
# category              Fisheries and aquaculture
# variable    Cont. to ME Wage and salary earners
# units                                Proportion
# magnitude                                Actual
# source                                     LEED
# data_value                                 39.4
# flag                                          F
#
#                                             2    \
# ...
