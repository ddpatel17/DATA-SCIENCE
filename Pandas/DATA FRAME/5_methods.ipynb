# %%
                    # Methos Of DataFrame : Data Manipulation & Sorting And Ranking

# %%
import pandas as pd

# %%
s1 = pd.read_csv("../../Data/marine economy.csv")
s1.head()
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag
# 0  Proportion    Actual   LEED        42.1    F
# 1  Proportion    Actual   LEED        39.4    F
# 2  Proportion    Actual   LEED        39.9    R
# 3  Proportion    Actual   LEED        40.8    F
# 4  Proportion    Actual   LEED        39.9    F

# %%
result = pd.DataFrame(s1)
result
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# ...

# %%
s2 = s1.copy()
s2
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# ...

# %%
s2.insert(8,'numbers','11111')

# %%
s2.head()
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag numbers
# 0  Proportion    Actual   LEED        42.1    F   11111
# 1  Proportion    Actual   LEED        39.4    F   11111
# 2  Proportion    Actual   LEED        39.9    R   11111
# 3  Proportion    Actual   LEED        40.8    F   11111
# 4  Proportion    Actual   LEED        39.9    F   11111

# %%
s2.insert(8,'flag','f,r',allow_duplicates=True)

# %%
s2.head()
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag flag numbers
# 0  Proportion    Actual   LEED        42.1    F  f,r   11111
# 1  Proportion    Actual   LEED        39.4    F  f,r   11111
# 2  Proportion    Actual   LEED        39.9    R  f,r   11111
# 3  Proportion    Actual   LEED        40.8    F  f,r   11111
# 4  Proportion    Actual   LEED        39.9    F  f,r   11111

# %%
s2.fillna(0)
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag flag numbers
# ...

# %%
s2.dropna(axis=1,inplace=False)
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source flag flag numbers
# ...

# %%
s2.dropna(axis=0,inplace=False)
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag flag numbers
# ...

# %%
s2 = s2.set_index('year').sort_index()  # help in find perticular filtered data.
a = s2.truncate(after='2007',axis=0,copy=True)
a
# Out:
#                            category                                 variable  \
# year
# 2007      Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 2007      Fisheries and aquaculture  Contribution to marine economy earnings
# 2007           Total marine economy                           Gross earnings
# 2007           Total marine economy                            Mean earnings
# 2007           Total marine economy                Contribution to total GDP
# 2007                       Shipping                  Wage and salary earners
# 2007      Fisheries and aquaculture                Contribution to total GDP
# 2007           Total marine economy                                      GDP
# 2007                       Shipping                                      GDP
# 2007      Fisheries and aquaculture                           Gross earnings
# 2007                       Shipping       Contribution to marine economy GDP
# ...

# %%
s2.convert_dtypes()
# Out:
#                        category                                 variable  \
# year
# 2007  Fisheries and aquaculture      Cont. to ME Wage and salary earners
# 2007  Fisheries and aquaculture  Contribution to marine economy earnings
# 2007       Total marine economy                           Gross earnings
# 2007       Total marine economy                            Mean earnings
# 2007       Total marine economy                Contribution to total GDP
# ...                         ...                                      ...
# 2021            Marine services                                      GDP
# 2021            Marine services       Contribution to marine economy GDP
# 2021            Marine services                Contribution to total GDP
# 2021       Total marine economy                           Gross earnings
# 2021            Marine services  Contribution to marine economy earnings
#
#            units  magnitude                  source  data_value flag flag  \
# year
# ...

# %%
s2_converted = s2.convert_dtypes()
print(s2_converted.dtypes)
# Out:
# category      string[python]
# variable      string[python]
# units         string[python]
# magnitude     string[python]
# source        string[python]
# data_value           Float64
# flag          string[python]
# flag          string[python]
# numbers       string[python]
# dtype: object

# %%
s2.sort_values(by='data_value',ascending=True,inplace=True)

# %%
s2.head()
# Out:
#                            category                            variable  \
# year
# 2017                Marine services                                 GDP
# 2017                Marine services  Contribution to marine economy GDP
# 2021  Marine tourism and recreation           Contribution to total GDP
# 2021         Government and defence           Contribution to total GDP
# 2016         Government and defence           Contribution to total GDP
#
#            units  magnitude                  source  data_value flag flag  \
# year
# 2017     Dollars  Thousands  Environmental Accounts     -6739.0    F  f,r
# 2017  Proportion     Actual  Environmental Accounts        -0.2    F  f,r
# 2021  Proportion     Actual  Environmental Accounts         0.0    P  f,r
# 2021  Proportion     Actual  Environmental Accounts         0.0    P  f,r
# 2016  Proportion     Actual  Environmental Accounts         0.0    F  f,r
#
#      numbers
# year
# 2017   11111
# 2017   11111
# 2021   11111
# ...

# %%
s2.sort_values(by='data_value',ascending=True,inplace=True)

# %%
s2.head()
# Out:
#                            category                            variable  \
# year
# 2017                Marine services                                 GDP
# 2017                Marine services  Contribution to marine economy GDP
# 2021  Marine tourism and recreation           Contribution to total GDP
# 2021         Government and defence           Contribution to total GDP
# 2016         Government and defence           Contribution to total GDP
#
#            units  magnitude                  source  data_value flag flag  \
# year
# 2017     Dollars  Thousands  Environmental Accounts     -6739.0    F  f,r
# 2017  Proportion     Actual  Environmental Accounts        -0.2    F  f,r
# 2021  Proportion     Actual  Environmental Accounts         0.0    P  f,r
# 2021  Proportion     Actual  Environmental Accounts         0.0    P  f,r
# 2016  Proportion     Actual  Environmental Accounts         0.0    F  f,r
#
#      numbers
# year
# 2017   11111
# 2017   11111
# 2021   11111
# ...

# %%
s2.sort_values(by='data_value',ascending=False,inplace=True) # sorted in descending

# %%
s2.head()
# Out:
#                   category variable    units  magnitude  \
# year
# 2011  Total marine economy      GDP  Dollars  Thousands
# 2020  Total marine economy      GDP  Dollars  Thousands
# 2010  Total marine economy      GDP  Dollars  Thousands
# 2012  Total marine economy      GDP  Dollars  Thousands
# 2019  Total marine economy      GDP  Dollars  Thousands
#
#                       source  data_value flag flag numbers
# year
# 2011  Environmental Accounts   4611116.0    F  f,r   11111
# 2020  Environmental Accounts   4568459.0    P  f,r   11111
# 2010  Environmental Accounts   4480573.0    F  f,r   11111
# 2012  Environmental Accounts   4412374.0    F  f,r   11111
# 2019  Environmental Accounts   4373290.0    F  f,r   11111

# %%
s2.sort_index()
# Out:
#                            category                                 variable  \
# year
# 2007                       Shipping                                      GDP
# 2007           Total marine economy                           Gross earnings
# 2007      Fisheries and aquaculture                Contribution to total GDP
# 2007  Marine tourism and recreation                  Wage and salary earners
# 2007              Offshore minerals                Contribution to total GDP
# ...                             ...                                      ...
# 2021      Fisheries and aquaculture  Contribution to marine economy earnings
# 2021                Marine services                  Wage and salary earners
# 2021  Marine tourism and recreation                  Wage and salary earners
# 2021                Marine services                Contribution to total GDP
# 2021              Offshore minerals                  Wage and salary earners
#
# ...

# %%
s2.sort_index(axis=0,ascending=False,inplace=True)

# %%
s2.head()
# Out:
#                   category                   variable       units  magnitude  \
# year
# 2021              Shipping                        GDP     Dollars  Thousands
# 2021  Total marine economy             Gross earnings     Dollars  Thousands
# 2021       Marine services  Contribution to total GDP  Proportion     Actual
# 2021     Offshore minerals  Contribution to total GDP  Proportion     Actual
# 2021              Shipping  Contribution to total GDP  Proportion     Actual
#
#                       source  data_value flag flag numbers
# year
# 2021  Environmental Accounts   2059736.0    P  f,r   11111
# 2021                    LEED   2321600.0    P  f,r   11111
# 2021  Environmental Accounts         0.1    P  f,r   11111
# 2021  Environmental Accounts         0.1    P  f,r   11111
# 2021  Environmental Accounts         0.6    P  f,r   11111

# %%
s2.sort_index(axis=1,ascending=True,inplace=True)

# %%
s2.head()
# Out:
#                   category  data_value flag flag  magnitude numbers  \
# year
# 2021              Shipping   2059736.0    P  f,r  Thousands   11111
# 2021  Total marine economy   2321600.0    P  f,r  Thousands   11111
# 2021       Marine services         0.1    P  f,r     Actual   11111
# 2021     Offshore minerals         0.1    P  f,r     Actual   11111
# 2021              Shipping         0.6    P  f,r     Actual   11111
#
#                       source       units                   variable
# year
# 2021  Environmental Accounts     Dollars                        GDP
# 2021                    LEED     Dollars             Gross earnings
# 2021  Environmental Accounts  Proportion  Contribution to total GDP
# 2021  Environmental Accounts  Proportion  Contribution to total GDP
# 2021  Environmental Accounts  Proportion  Contribution to total GDP

# %%
s2['data_value_Rank']=s2['data_value'].rank(method='average',ascending=False)

# %%
s2.head()
# Out:
#                   category  data_value flag flag  magnitude numbers  \
# year
# 2021              Shipping   2059736.0    P  f,r  Thousands   11111
# 2021  Total marine economy   2321600.0    P  f,r  Thousands   11111
# 2021       Marine services         0.1    P  f,r     Actual   11111
# 2021     Offshore minerals         0.1    P  f,r     Actual   11111
# 2021              Shipping         0.6    P  f,r     Actual   11111
#
#                       source       units                   variable  \
# year
# 2021  Environmental Accounts     Dollars                        GDP
# 2021                    LEED     Dollars             Gross earnings
# 2021  Environmental Accounts  Proportion  Contribution to total GDP
# 2021  Environmental Accounts  Proportion  Contribution to total GDP
# 2021  Environmental Accounts  Proportion  Contribution to total GDP
#
#       data_value_Rank
# year
# 2021             25.0
# 2021             18.0
# 2021            660.5
# 2021            660.5
# ...
