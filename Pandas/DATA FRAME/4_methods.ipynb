# %%
                                # Methos Of DataFrame : Data Mnipulation

# %%
import pandas as pd

# %%
s1 = pd.read_csv("../../Data/marine economy.csv")
s1.head()
# Out:
#    year                   category                             variable  \
# 0  2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1  2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2  2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3  2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4  2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
#
#         units magnitude source  data_value flag
# 0  Proportion    Actual   LEED        42.1    F
# 1  Proportion    Actual   LEED        39.4    F
# 2  Proportion    Actual   LEED        39.9    R
# 3  Proportion    Actual   LEED        40.8    F
# 4  Proportion    Actual   LEED        39.9    F

# %%
result = pd.DataFrame(s1)
result
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# ...

# %%
s1.copy()
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# ...

# %%
a = s1.assign(numbers=11111)
a
# Out:
#      year                   category                             variable  \
# 0    2007  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    2008  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    2009  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    2010  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    2011  Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..    ...                        ...                                  ...
# 709  2017       Total marine economy              Wage and salary earners
# 710  2018       Total marine economy              Wage and salary earners
# 711  2019       Total marine economy              Wage and salary earners
# 712  2020       Total marine economy              Wage and salary earners
# 713  2021       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag  numbers
# ...

# %%
b = a.pop('numbers') # error output is not satisfy.
b
# Out:
# 0      11111
# 1      11111
# 2      11111
# 3      11111
# 4      11111
#        ...
# 709    11111
# 710    11111
# 711    11111
# 712    11111
# 713    11111
# Name: numbers, Length: 714, dtype: int64

# %%
s1.drop('year',axis=1,inplace=True)

# %%
s1.rename(columns={'category':'Category'})
# Out:
#                       Category                             variable  \
# 0    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..                         ...                                  ...
# 709       Total marine economy              Wage and salary earners
# 710       Total marine economy              Wage and salary earners
# 711       Total marine economy              Wage and salary earners
# 712       Total marine economy              Wage and salary earners
# 713       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# 0    Proportion    Actual   LEED        42.1    F
# ...

# %%
s1.replace('Actual','actual')
# Out:
#                       category                             variable  \
# 0    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 1    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 2    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 3    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# 4    Fisheries and aquaculture  Cont. to ME Wage and salary earners
# ..                         ...                                  ...
# 709       Total marine economy              Wage and salary earners
# 710       Total marine economy              Wage and salary earners
# 711       Total marine economy              Wage and salary earners
# 712       Total marine economy              Wage and salary earners
# 713       Total marine economy              Wage and salary earners
#
#           units magnitude source  data_value flag
# 0    Proportion    actual   LEED        42.1    F
# ...

# %%
s1.astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 s1.astype('float64')
#
# File e:\DATA SCIENCE\venv\Lib\site-packages\pandas\core\generic.py:6662, in NDFrame.astype(self, dtype, copy, errors)
#    6656     results = [
#    6657         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6658     ]
#    6660 else:
#    6661     # else, only a single dtype is given
# -> 6662     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6663     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6664     return res.__finalize__(self, method="astype")
#
# File e:\DATA SCIENCE\venv\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
mask = s1.mask(s1['data_value']>30)
mask
# Out:
#     category variable units magnitude source  data_value flag
# 0        NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 1        NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 2        NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 3        NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 4        NaN      NaN   NaN       NaN    NaN         NaN  NaN
# ..       ...      ...   ...       ...    ...         ...  ...
# 709      NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 710      NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 711      NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 712      NaN      NaN   NaN       NaN    NaN         NaN  NaN
# 713      NaN      NaN   NaN       NaN    NaN         NaN  NaN
#
# [714 rows x 7 columns]
